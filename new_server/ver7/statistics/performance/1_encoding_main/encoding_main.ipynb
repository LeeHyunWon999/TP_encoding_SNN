# %% [markdown]
# 정제한 데이터를 다시 이쪽에 맞게 정제한다.

# %%
# 사전 변수
csv_dir = '/home/hschoi/leehyunwon/ECG-SNN/new_server/ver7/statistics/tensorboard_to_pandas/faultD_1.csv'
savefile_name = 'faultD_1.csv'

# test 데이터인 경우(inference 시간 측정용)
# metric_columns = ['valid_Accuracy','valid_F1_weighted', 'valid_AUROC_macro', 'valid_auprc', 'elapsed_time']  # 필요한 metric 열 이름 지정

# test 데이터 아닌 경우 이거로 지정
metric_columns = ['epoch','valid_Accuracy','valid_F1_weighted', 'valid_AUROC_macro', 'valid_auprc', 'total elapsed minute', 'minute per epoch']  # 필요한 metric 열 이름 지정

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV 파일 불러오기
data = pd.read_csv(csv_dir)

# 폴더명에서 시간 기록(yyyy-mm-dd-hh-mm-ss)을 추출하여 그룹화 키 추가
def extract_time_key(source_dir):
    return "-".join(source_dir.split("_")[:-2])

data['time_key'] = data['source_dir'].apply(extract_time_key)

# metric에 해당하는 열만 추출 (acc, auroc, f1_score 같은 열)
metric_data = data[['time_key'] + metric_columns]

print(metric_data)

# 시간 키 단위로 그룹화하여 평균과 표준편차차 계산
grouped_metrics = metric_data.groupby('time_key').agg(['mean', 'std'])

# 결과 출력
# print(grouped_metrics)
# Out:
#                 time_key  epoch  valid_Accuracy  valid_F1_weighted  \
# 0           burst-faultD   12.0        0.453046           0.331249
# 1           burst-faultD   10.0        0.333486           0.346866
# 2           burst-faultD   12.0        0.474794           0.443110
# 3           burst-faultD    2.0        0.479835           0.332077
# 4           burst-faultD  742.0        0.500000           0.491599
# 5   filter-CNN-2D-faultD  997.0        0.786532           0.779695
# 6   filter-CNN-2D-faultD  959.0        0.806230           0.800088
# 7   filter-CNN-2D-faultD  998.0        0.773602           0.767187
# 8   filter-CNN-2D-faultD  996.0        0.807058           0.803453
# 9   filter-CNN-2D-faultD  957.0        0.811641           0.808596
# 10        poisson-faultD  896.0        0.312872           0.259730
# 11        poisson-faultD  290.0        0.086578           0.013797
# 12        poisson-faultD   15.0        0.087076           0.013950
# 13        poisson-faultD   65.0        0.324015           0.261828
# 14        poisson-faultD  216.0        0.092576           0.015688
# 15          TP-2D-faultD  930.0        0.592762           0.534391
# 16          TP-2D-faultD    1.0        0.475492           0.306465
# 17          TP-2D-faultD    1.0        0.445005           0.274088
# 18          TP-2D-faultD    1.0        0.433089           0.261765
# 19          TP-2D-faultD    1.0        0.439963           0.268851
#
#     valid_AUROC_macro  valid_auprc  total elapsed minute  minute per epoch
# 0            0.648097     0.441134             13.725204          1.143767
# 1            0.588945     0.390740             11.485705          1.148571
# 2            0.622595     0.421231              6.451036          0.537586
# 3            0.669057     0.479620              0.875922          0.437961
# 4            0.650218     0.443710            327.387430          0.441223
# 5            0.933008     0.914814            140.366331          0.140789
# 6            0.945559     0.933421            130.508236          0.136088
# 7            0.926292     0.892353            136.613893          0.136888
# 8            0.945036     0.930249            135.407519          0.135951
# 9            0.943852     0.929057            128.432781          0.134204
# 10           0.532308     0.354963             88.079848          0.098303
# 11           0.579588     0.387255             28.765947          0.099193
# 12           0.543119     0.367401              1.448529          0.096569
# 13           0.538189     0.366689              6.331916          0.097414
# 14           0.539104     0.360241             21.168907          0.098004
# 15           0.690794     0.580632           3411.408009          3.668181
# 16           0.672856     0.431613              4.028555          4.028555
# 17           0.500000     0.333333              3.563812          3.563812
# 18           0.500000     0.333333              3.527567          3.527567
# 19           0.500000     0.333333              3.974491          3.974491

# %%
# 그룹화 결과에 그룹화 키를 열로 복구
grouped_metrics_reset = grouped_metrics.reset_index()

# CSV로 저장
grouped_metrics_reset.to_csv(savefile_name, index=False)
