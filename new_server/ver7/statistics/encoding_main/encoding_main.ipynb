# %% [markdown]
# 정제한 데이터를 다시 이쪽에 맞게 정제한다.

# %%
# 사전 변수
csv_dir = '/home/hschoi/leehyunwon/ECG-SNN/new_server/ver7/statistics/tensorboard_to_pandas/gesture_2.csv'
savefile_name = 'gesture_2.csv'

# test 데이터인 경우(inference 시간 측정용)
# metric_columns = ['valid_Accuracy','valid_F1_weighted', 'valid_AUROC_macro', 'valid_auprc', 'elapsed_time']  # 필요한 metric 열 이름 지정

# test 데이터 아닌 경우 이거로 지정
metric_columns = ['valid_Accuracy','valid_F1_weighted', 'valid_AUROC_macro', 'valid_auprc']  # 필요한 metric 열 이름 지정

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV 파일 불러오기
data = pd.read_csv(csv_dir)

# 폴더명에서 시간 기록(yyyy-mm-dd-hh-mm-ss)을 추출하여 그룹화 키 추가
def extract_time_key(source_dir):
    return "-".join(source_dir.split("_")[:-2])

data['time_key'] = data['source_dir'].apply(extract_time_key)

# metric에 해당하는 열만 추출 (acc, auroc, f1_score 같은 열)
metric_data = data[['time_key'] + metric_columns]

print(metric_data)

# 시간 키 단위로 그룹화하여 평균과 표준편차차 계산
grouped_metrics = metric_data.groupby('time_key').agg(['mean', 'std'])

# 결과 출력
# print(grouped_metrics)
# Out:
#                    time_key  valid_Accuracy  valid_F1_weighted  \
# 0             burst-gesture        0.935844           0.935994
# 1             burst-gesture        0.940028           0.940035
# 2             burst-gesture        0.932961           0.932674
# 3             burst-gesture        0.927374           0.927034
# 4             burst-gesture        0.930168           0.930389
# 5     filter-CNN-2D-gesture        0.962343           0.962146
# 6     filter-CNN-2D-gesture        0.952580           0.952718
# 7     filter-CNN-2D-gesture        0.958101           0.957965
# 8     filter-CNN-2D-gesture        0.953911           0.953613
# 9     filter-CNN-2D-gesture        0.958101           0.957812
# 10          poisson-gesture        0.958159           0.958275
# 11          poisson-gesture        0.969317           0.969448
# 12          poisson-gesture        0.962291           0.962279
# 13          poisson-gesture        0.970670           0.970680
# 14          poisson-gesture        0.973464           0.973450
# 15            TP-2D-gesture        0.534170           0.495916
# 16            TP-2D-gesture        0.503487           0.464052
# 17            TP-2D-gesture        0.576816           0.541941
# 18            TP-2D-gesture        0.512570           0.463731
# 19            TP-2D-gesture        0.527933           0.486708
# 20  TP-learnable-2D-gesture        0.804742           0.798068
# 21  TP-learnable-2D-gesture        0.854951           0.855383
# 22  TP-learnable-2D-gesture        0.857542           0.853536
# 23  TP-learnable-2D-gesture        0.854749           0.852498
# 24  TP-learnable-2D-gesture        0.856145           0.855456
#
#     valid_AUROC_macro  valid_auprc
# 0            0.993397     0.966708
# 1            0.990843     0.960408
# 2            0.990767     0.965426
# 3            0.995600     0.976764
# 4            0.995183     0.974903
# 5            0.997376     0.984221
# 6            0.996137     0.980784
# 7            0.997855     0.988598
# 8            0.996753     0.985201
# 9            0.996299     0.981672
# 10           0.998343     0.991021
# 11           0.994872     0.982624
# 12           0.997985     0.989574
# 13           0.997758     0.989772
# 14           0.998055     0.990876
# 15           0.881037     0.561718
# 16           0.869071     0.519461
# 17           0.890645     0.593087
# 18           0.881413     0.546239
# 19           0.884661     0.563345
# 20           0.972120     0.875045
# 21           0.974699     0.910666
# 22           0.980852     0.921393
# 23           0.978222     0.914797
# 24           0.978286     0.915734

# %%
# 그룹화 결과에 그룹화 키를 열로 복구
grouped_metrics_reset = grouped_metrics.reset_index()

# CSV로 저장
grouped_metrics_reset.to_csv(savefile_name, index=False)
