# %% [markdown]
# 정제한 데이터를 다시 이쪽에 맞게 정제한다.

# %%
# 사전 변수
csv_dir = '/home/hschoi/leehyunwon/ECG-SNN/new_server/ver7/statistics/tensorboard_to_pandas/CinC_original_1.csv'
savefile_name = 'CinC_original_1.csv'

# test 데이터인 경우(inference 시간 측정용)
# metric_columns = ['valid_Accuracy','valid_F1_micro', 'valid_AUROC_macro', 'valid_auprc', 'elapsed_time']  # 필요한 metric 열 이름 지정

# test 데이터 아닌 경우 이거로 지정
metric_columns = ['valid_Accuracy','valid_F1_micro', 'valid_AUROC_macro', 'valid_auprc']  # 필요한 metric 열 이름 지정

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV 파일 불러오기
data = pd.read_csv(csv_dir)

# 폴더명에서 시간 기록(yyyy-mm-dd-hh-mm-ss)을 추출하여 그룹화 키 추가
def extract_time_key(source_dir):
    return "-".join(source_dir.split("_")[:-2])

data['time_key'] = data['source_dir'].apply(extract_time_key)

# metric에 해당하는 열만 추출 (acc, auroc, f1_score 같은 열)
metric_data = data[['time_key'] + metric_columns]

print(metric_data)

# 시간 키 단위로 그룹화하여 평균과 표준편차차 계산
grouped_metrics = metric_data.groupby('time_key').agg(['mean', 'std'])

# 결과 출력
# print(grouped_metrics)
# Out:
#                        time_key  valid_Accuracy  valid_F1_micro  \
# 0           burst-CinC-original        0.813272        0.187919
# 1           burst-CinC-original        0.790123        0.218391
# 2           burst-CinC-original        0.759259        0.235294
# 3           burst-CinC-original        0.791667        0.219653
# 4           burst-CinC-original        0.788580        0.243094
# 5   filter-CNN-2D-CinC-original        0.825617        0.542510
# 6   filter-CNN-2D-CinC-original        0.802469        0.525926
# 7   filter-CNN-2D-CinC-original        0.797840        0.540351
# 8   filter-CNN-2D-CinC-original        0.785494        0.547231
# 9   filter-CNN-2D-CinC-original        0.788580        0.475096
# 10        poisson-CinC-original        0.776235        0.435798
# 11        poisson-CinC-original        0.785494        0.446215
# 12        poisson-CinC-original        0.760802        0.463668
# 13        poisson-CinC-original        0.782407        0.459770
# 14        poisson-CinC-original        0.760802        0.382470
# 15          TP-2D-CinC-original        0.810185        0.000000
# 16          TP-2D-CinC-original        0.791667        0.014599
# 17          TP-2D-CinC-original        0.631173        0.255452
# 18          TP-2D-CinC-original        0.209877        0.341902
# 19          TP-2D-CinC-original        0.790123        0.000000
#
#     valid_AUROC_macro  valid_auprc
# 0            0.545482     0.261542
# 1            0.551298     0.309129
# 2            0.545517     0.273613
# 3            0.551040     0.312883
# 4            0.558421     0.304652
# 5            0.718072     0.484806
# 6            0.699506     0.496149
# 7            0.711550     0.488919
# 8            0.728411     0.498902
# 9            0.666418     0.489216
# 10           0.653357     0.395010
# 11           0.648265     0.415451
# 12           0.661355     0.409662
# 13           0.659544     0.430877
# 14           0.611041     0.388906
# 15           0.500000     0.221631
# 16           0.503676     0.223464
# 17           0.509713     0.222671
# 18           0.502913     0.202408
# 19           0.500000     0.246152

# %%
# 그룹화 결과에 그룹화 키를 열로 복구
grouped_metrics_reset = grouped_metrics.reset_index()

# CSV로 저장
grouped_metrics_reset.to_csv(savefile_name, index=False)
