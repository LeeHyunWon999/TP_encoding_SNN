# %% [markdown]
# 정제한 데이터를 다시 이쪽에 맞게 정제한다.

# %%
# 사전 변수
csv_dir = '/home/hschoi/leehyunwon/ECG-SNN/new_server/ver7/statistics/tensorboard_to_pandas/gesture_1.csv'
savefile_name = 'gesture_1.csv'

# test 데이터인 경우(inference 시간 측정용)
# metric_columns = ['valid_Accuracy','valid_F1_micro', 'valid_AUROC_macro', 'valid_auprc', 'elapsed_time']  # 필요한 metric 열 이름 지정

# test 데이터 아닌 경우 이거로 지정
metric_columns = ['valid_Accuracy','valid_F1_micro', 'valid_AUROC_macro', 'valid_auprc']  # 필요한 metric 열 이름 지정

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV 파일 불러오기
data = pd.read_csv(csv_dir)

# 폴더명에서 시간 기록(yyyy-mm-dd-hh-mm-ss)을 추출하여 그룹화 키 추가
def extract_time_key(source_dir):
    return "-".join(source_dir.split("_")[:-2])

data['time_key'] = data['source_dir'].apply(extract_time_key)

# metric에 해당하는 열만 추출 (acc, auroc, f1_score 같은 열)
metric_data = data[['time_key'] + metric_columns]

print(metric_data)

# 시간 키 단위로 그룹화하여 평균과 표준편차차 계산
grouped_metrics = metric_data.groupby('time_key').agg(['mean', 'std'])

# 결과 출력
# print(grouped_metrics)
# Out:
#                    time_key  valid_Accuracy  valid_F1_micro  \
# 0             burst-gesture        0.947001        0.947001
# 1             burst-gesture        0.951186        0.951186
# 2             burst-gesture        0.944134        0.944134
# 3             burst-gesture        0.931564        0.931564
# 4             burst-gesture        0.946927        0.946927
# 5     filter-CNN-2D-gesture        0.959554        0.959554
# 6     filter-CNN-2D-gesture        0.953975        0.953975
# 7     filter-CNN-2D-gesture        0.953911        0.953911
# 8     filter-CNN-2D-gesture        0.952514        0.952514
# 9     filter-CNN-2D-gesture        0.958101        0.958101
# 10          poisson-gesture        0.967922        0.967922
# 11          poisson-gesture        0.960948        0.960948
# 12          poisson-gesture        0.973464        0.973464
# 13          poisson-gesture        0.973464        0.973464
# 14          poisson-gesture        0.979050        0.979050
# 15  TP-learnable-2D-gesture        0.881450        0.881450
# 16  TP-learnable-2D-gesture        0.885635        0.885635
# 17  TP-learnable-2D-gesture        0.885475        0.885475
# 18  TP-learnable-2D-gesture        0.865922        0.865922
# 19  TP-learnable-2D-gesture        0.856145        0.856145
#
#     valid_AUROC_macro  valid_auprc
# 0            0.996624     0.980504
# 1            0.991781     0.970010
# 2            0.995990     0.980105
# 3            0.997266     0.985374
# 4            0.997650     0.986612
# 5            0.997471     0.984155
# 6            0.994797     0.979218
# 7            0.997748     0.987364
# 8            0.996304     0.983596
# 9            0.996034     0.982098
# 10           0.999108     0.994517
# 11           0.995742     0.982509
# 12           0.998835     0.993199
# 13           0.998298     0.992801
# 14           0.998440     0.992091
# 15           0.981721     0.932830
# 16           0.982258     0.938475
# 17           0.985902     0.942734
# 18           0.983477     0.925295
# 19           0.987249     0.945132

# %%
# 그룹화 결과에 그룹화 키를 열로 복구
grouped_metrics_reset = grouped_metrics.reset_index()

# CSV로 저장
grouped_metrics_reset.to_csv(savefile_name, index=False)
