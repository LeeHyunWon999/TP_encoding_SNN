# %% [markdown]
# 정제한 데이터를 다시 이쪽에 맞게 정제한다.

# %%
# 사전 변수
csv_dir = '/home/hschoi/leehyunwon/ECG-SNN/new_server/ver7/statistics/tensorboard_to_pandas/CinC_original_2.csv'
savefile_name = 'CinC_original_2.csv'

# test 데이터인 경우(inference 시간 측정용)
# metric_columns = ['valid_Accuracy','valid_F1_micro', 'valid_AUROC_macro', 'valid_auprc', 'elapsed_time']  # 필요한 metric 열 이름 지정

# test 데이터 아닌 경우 이거로 지정
metric_columns = ['valid_Accuracy','valid_F1_micro', 'valid_AUROC_macro', 'valid_auprc']  # 필요한 metric 열 이름 지정

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV 파일 불러오기
data = pd.read_csv(csv_dir)

# 폴더명에서 시간 기록(yyyy-mm-dd-hh-mm-ss)을 추출하여 그룹화 키 추가
def extract_time_key(source_dir):
    return "-".join(source_dir.split("_")[:-2])

data['time_key'] = data['source_dir'].apply(extract_time_key)

# metric에 해당하는 열만 추출 (acc, auroc, f1_score 같은 열)
metric_data = data[['time_key'] + metric_columns]

print(metric_data)

# 시간 키 단위로 그룹화하여 평균과 표준편차차 계산
grouped_metrics = metric_data.groupby('time_key').agg(['mean', 'std'])

# 결과 출력
# print(grouped_metrics)
# Out:
#                        time_key  valid_Accuracy  valid_F1_micro  \
# 0           burst-CinC-original        0.709877        0.308824
# 1           burst-CinC-original        0.763889        0.331878
# 2           burst-CinC-original        0.680556        0.347003
# 3           burst-CinC-original        0.745370        0.372624
# 4           burst-CinC-original        0.748457        0.306383
# 5   filter-CNN-2D-CinC-original        0.771605        0.584270
# 6   filter-CNN-2D-CinC-original        0.734568        0.586538
# 7   filter-CNN-2D-CinC-original        0.736111        0.589928
# 8   filter-CNN-2D-CinC-original        0.759259        0.591623
# 9   filter-CNN-2D-CinC-original        0.723765        0.574822
# 10        poisson-CinC-original        0.745370        0.501511
# 11        poisson-CinC-original        0.682099        0.523148
# 12        poisson-CinC-original        0.669753        0.513636
# 13        poisson-CinC-original        0.783951        0.548387
# 14        poisson-CinC-original        0.679012        0.518519
# 15          TP-2D-CinC-original        0.523148        0.317881
# 16          TP-2D-CinC-original        0.530864        0.355932
# 17          TP-2D-CinC-original        0.578704        0.386517
# 18          TP-2D-CinC-original        0.609568        0.369077
# 19          TP-2D-CinC-original        0.527778        0.351695
#
#     valid_AUROC_macro  valid_auprc
# 0            0.568827     0.246836
# 1            0.585995     0.298899
# 2            0.578421     0.300321
# 3            0.605570     0.324153
# 4            0.570830     0.276058
# 5            0.799907     0.461884
# 6            0.794233     0.486102
# 7            0.795285     0.483608
# 8            0.792773     0.501834
# 9            0.784697     0.484286
# 10           0.718351     0.397199
# 11           0.736730     0.435922
# 12           0.726499     0.402313
# 13           0.730228     0.499673
# 14           0.732077     0.434527
# 15           0.546969     0.228398
# 16           0.562730     0.239194
# 17           0.596648     0.269315
# 18           0.589846     0.266194
# 19           0.558077     0.254315

# %%
# 그룹화 결과에 그룹화 키를 열로 복구
grouped_metrics_reset = grouped_metrics.reset_index()

# CSV로 저장
grouped_metrics_reset.to_csv(savefile_name, index=False)
